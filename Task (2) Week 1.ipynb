# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
import pandas as pd 

df = pd.read_csv('Task (2) Dataset.csv')

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#            City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0      Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1      Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2      Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3      Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4      Abudhabi  2023-07-07 12:01:30                 8         20       62.1
# ...         ...                  ...               ...        ...        ...
# 66634    Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635    Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636    Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637    Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638    Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   62772 non-null  float64
#  8   TravelTimeLive       62772 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
df.isnull().sum()
# Out:
# City                      0
# Datetime                  0
# TrafficIndexLive          0
# JamsCount                 0
# JamsDelay                 0
# JamsLength                0
# TrafficIndexWeekAgo       0
# TravelTimeHistoric     3867
# TravelTimeLive         3867
# dtype: int64

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
import seaborn as sns

# %%
co = df.drop(columns=['City','Datetime'])

# %%
h= co.corr()

# %%
sns.heatmap(h,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
df.columns
# Out:
# Index(['City', 'Datetime', 'TrafficIndexLive', 'JamsCount', 'JamsDelay',
#        'JamsLength', 'TrafficIndexWeekAgo', 'TravelTimeHistoric',
#        'TravelTimeLive'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x='TrafficIndexLive',y='JamsDelay',hue='City')
# Out:
# <Axes: xlabel='TrafficIndexLive', ylabel='JamsDelay'>

# %%
sns.scatterplot(data=df, x='TrafficIndexWeekAgo',y='TravelTimeHistoric',hue='City')
# Out:
# <Axes: xlabel='TrafficIndexWeekAgo', ylabel='TravelTimeHistoric'>

# %%
df['Datetime']= pd.to_datetime(df['Datetime'])

# %%
df['JamsLength'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='JamsLength'>

# %%
df['JamsLength'].value_counts().mean()
# Out:
# 16.108049311094998

# %%
df['JamsDelay'].value_counts().mean()
# Out:
# 5.273324364960038

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
#plt.pie(df['TrafficIndexWeekAgo'].sort_values().head(),labels= df['City'].sort_values().head())

# %%
df['Datetime'].plot.line()
# Out:
# <Axes: >

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.pairplot(df)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df['JamsCount'])
# Out:
# <Axes: ylabel='JamsCount'>

# %%
sns.boxplot(df[''])
# Out:
# <Axes: ylabel='JamsLength'>

# %%
sns.violinplot(data=df['JamsCount'])
# Out:
# <Axes: ylabel='JamsCount'>

# %%
sns.violinplot(data=df['JamsLength'],orient='h',bw=0.5)
# Out:
# C:\Users\afmt5\AppData\Local\Temp\ipykernel_21520\3627204095.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.5`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(data=df['JamsLength'],orient='h',bw=0.5)
# <Axes: xlabel='JamsLength'>

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
df.columns
# Out:
# Index(['City', 'Datetime', 'TrafficIndexLive', 'JamsCount', 'JamsDelay',
#        'JamsLength', 'TrafficIndexWeekAgo', 'TravelTimeHistoric',
#        'TravelTimeLive'],
#       dtype='object')

# %%
#plt.figure(20,5)
sns.histplot(data=df,x='Datetime',y='City')
# Out:
# <Axes: xlabel='Datetime', ylabel='City'>

# %%
#plt.figure(20,5)
sns.histplot(data=df,y='City')
# Out:
# <Axes: xlabel='Count', ylabel='City'>

# %%
#plt.figure(20,5)
sns.histplot(data=df,x='JamsDelay',y='City')
# Out:
# <Axes: xlabel='JamsDelay', ylabel='City'>

# %%
df['JamsLength'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['City', 'Datetime', 'TrafficIndexLive', 'JamsCount', 'JamsDelay',
#        'JamsLength', 'TrafficIndexWeekAgo', 'TravelTimeHistoric',
#        'TravelTimeLive'],
#       dtype='object')

# %%
df['TravelTimeHistoric'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hexbin(x='TrafficIndexWeekAgo',y='TravelTimeHistoric',gridsize=15)
# Out:
# <Axes: xlabel='TrafficIndexWeekAgo', ylabel='TravelTimeHistoric'>

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# - as show in colume TravelTimeHistoric the time between 60 to 70 munint  it has more number  of TraveTravelTimeHistoric

# %% [markdown]
# - the Doha ,Riyadh ,Kuwait ,Cairo ,Dubai has more traffic

# %% [markdown]
# - the number between 0 to 200 km has more frequency Length traffic

# %% [markdown]
# - the mean of JamsDelay almost 5 day

# %% [markdown]
# - the mean of JamsLength almost 16 km

# %% [markdown]
# - there are meny outlier point as show in figer

# %% [markdown]
# - riyaed the most JamsDelay asv show in hostgrim
